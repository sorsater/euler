# %% [markdown]
# Triangle, pentagonal, and hexagonal numbers are generated by the following formulae:
#
# ```
# Triangle	 	Tn=n(n+1)/2	 	1, 3, 6, 10, 15, ...
# Pentagonal	 	Pn=n(3n−1)/2	 	1, 5, 12, 22, 35, ...
# Hexagonal	 	Hn=n(2n−1)	 	1, 6, 15, 28, 45, ...
# It can be verified that T285 = P165 = H143 = 40755.
# ```
#
# Find the next triangle number that is also pentagonal and hexagonal.

# %%
def triangle(n):
    return int(n*(n+1)/2)

def pentagonal(n):
    return int(n*(3*n-1)/2)

def hexagonal(n):
    return int(n*(2*n-1))

# %%
i = 1
triangles = set()
pentagonals = set()
hexagonals = set()
# We loop only for triangles as the n for the others always are smaller
res = []
while True:
    tri = triangle(i)
    pen = pentagonal(i)
    hexa = hexagonal(i)
    pentagonals.add(pen)
    hexagonals.add(hexa)
    if tri in pentagonals and tri in hexagonals:
        res.append(tri)
        if tri > 40755:
            break
    i += 1

print(res[-1])
# Out:
# 1533776805
